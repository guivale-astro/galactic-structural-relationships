# %%
import pandas as pd
import pandas.plotting as pdplt
import numpy as np
import astropy as ast
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_mass = pd.read_csv("catalogs/EGS_stellar_mass_noon.csv")
df_mass = df_mass[df_mass > -90]
#display(df_mass)

df_phys = pd.read_csv("catalogs/EGS_physical_properties_noon.csv")
df_phys = df_phys[df_phys > -90]
#display(df_phys)

df_reds = pd.read_csv("catalogs/EGS_redshift_noon.csv")
#df_reds = df_reds.iloc[df_reds.iloc[:,[4,56]] > -90]
#display(df_reds)

df_mult = pd.read_csv("catalogs/EGS_multiband_noon.csv")
#df_mult = df_mult[df_mult > -90]
#display(df_mult)

# %%
plt.figure(figsize = (15, 8))

#plt.grid()
#bins = 20
import matplotlib
matplotlib.rcParams['axes.axisbelow'] = False

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())
sns.histplot(df_reds["z_best"], bins = bins, color = "coral", alpha = 0.7, edgecolor = 'black', linewidth = 2)
#sns.kdeplot(df_reds["z_best"], fill = True, linewidth = 20)

min_ylim, max_ylim = plt.ylim()
x = df_reds["z_best"]
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*1.01, max_ylim*0.9, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)

matplotlib.rc('xtick', labelsize=25) 
matplotlib.rc('ytick', labelsize=25) 

plt.xlabel('redshift', fontsize = 30)
plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)

plt.xticks(np.round(np.arange(1.535, 2.52, step= (2.5-1.51)/15), decimals=2))
plt.title('Redshift distribution at 1.5 < z < 2.5', fontsize = 35)

#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30)

plt.plot()

matplotlib.rcdefaults()

# %%
plt.figure(figsize = (15, 8))

import matplotlib
matplotlib.rcParams['axes.axisbelow'] = False

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())
sns.histplot(df_mass['M_neb_med'], bins = bins, color = "darkcyan", alpha = 0.7, edgecolor = 'black', linewidth = 2)


min_ylim, max_ylim = plt.ylim()
x = df_mass['M_neb_med']
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*1.05, max_ylim*0.9, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)



plt.xlabel('$\mathregular{log_{10}(M \; [M_\odot])}$', fontsize = 30)
#plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)

min_val = df_mass['M_neb_med'].min()
max_val = df_mass['M_neb_med'].max()
val_width = max_val - min_val
n_bins = 15
bin_width = val_width/n_bins

plt.xticks(np.around(np.arange(min_val-bin_width/2, max_val+bin_width/2, bin_width), decimals = 2))
plt.title('Stellar mass distribution at 1.5 < z < 2.5', fontsize = 35)

#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30)
plt.plot()

matplotlib.rcdefaults()

# %%
plt.figure(figsize = (15, 8))

#plt.grid()
#bins = 20
import matplotlib
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=25) 
matplotlib.rcParams['axes.axisbelow'] = False

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())
sns.histplot(df_phys['VMag_6a_tau^NEB'], bins = bins, color = "olivedrab", alpha = 0.7, edgecolor = 'black', linewidth = 2)


min_ylim, max_ylim = plt.ylim()
x = df_phys['VMag_6a_tau^NEB']
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*0.92, max_ylim*0.9, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)


plt.xlabel('$\mathregular{M_V \; [mag]}$', fontsize = 30)
#plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)


min_val = df_phys['VMag_6a_tau^NEB'].min()
max_val = df_phys['VMag_6a_tau^NEB'].max()
val_width = max_val - min_val
n_bins = 15
bin_width = val_width/n_bins
plt.xticks(np.around(np.arange(min_val-bin_width/2, max_val+bin_width/2, bin_width), decimals = 1))


plt.title('$\mathregular{M_V}$ distribution at 1.5 < z < 2.5', fontsize = 35)

#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30)

plt.plot()

matplotlib.rcdefaults()

# %%
plt.figure(figsize = (15, 8))

#plt.grid()
#bins = 20
import matplotlib
#matplotlib.rc('xtick', labelsize=25) 
#matplotlib.rc('ytick', labelsize=25) 
matplotlib.rcParams['axes.axisbelow'] = False

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())
sns.histplot(np.log10(df_phys['SFR_14a']), bins = bins, color = "mediumpurple", alpha = 0.7, edgecolor = 'black', linewidth = 2)


min_ylim, max_ylim = plt.ylim()
x = np.log10(df_phys['SFR_14a'])
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*2, max_ylim*0.9, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)


plt.xlabel('$\mathregular{log_{10}(SFR \; [M_\odot \; yr^{-1}])}$', fontsize = 30)
plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)

plt.xticks(np.round(np.arange(-3.125, 8, step= (6)/15), decimals=2))
plt.title('$\mathregular{log_{10}(SFR)}$ distribution at 1.5 < z < 2.5', fontsize = 35)

#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30)

plt.plot()

matplotlib.rcdefaults()

# %%
area = pd.DataFrame(df_mult['ISOAREAF_IMAGE'])
area_scale = 0.0395 * 0.0395

from astropy.cosmology import Planck15
from astropy import units as u

area *= area_scale
radius = np.sqrt(area/np.pi)
radius.columns = ['radius (arcsec)']
z = pd.DataFrame(df_reds['z_best'])
radius2 = radius['radius (arcsec)']*(1+z['z_best'])
from astropy.table import Table
z_1 = pd.DataFrame(df_reds['z_best'])
z_1 = Table.from_pandas(z_1)
radius_arcsec = np.array(radius)*u.arcsec
z_1 = df_reds['z_best']
radio = []
i = 0

while i <= len(z_1)-1:
    r_ang = Planck15.kpc_proper_per_arcmin(z_1[i])/60

    r = r_ang * radius_arcsec[i][0]
    
    radio.append(r.to_value())
    i += 1
    
radio = pd.DataFrame(radio)
radio.columns = ['radius']



plt.figure(figsize = (15, 8))


#plt.grid()
#bins = 20
import matplotlib
matplotlib.rcParams['axes.axisbelow'] = False


rad = np.log10(pd.DataFrame(radio**2*np.pi))
rad.columns = ['radius']

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())
sns.histplot(rad, bins = bins, color = "royalblue", alpha = 0.7, edgecolor = 'black', linewidth = 2)

min_ylim, max_ylim = plt.ylim()
x = rad['radius']
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*1.1, max_ylim*0.8, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)


plt.xlabel('$\mathregular{log_{10}(isoarea \; [kpc^2])}$', fontsize = 30)
plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)

plt.xticks(np.round(np.arange(-0.16, 3, step= (2.91)/15), decimals=2))
plt.title('$\mathregular{log_{10}(isoarea)}$ distribution at 1.5 < z < 2.5', fontsize = 35)
plt.legend([], [], frameon=False)
#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30) 

plt.plot()

matplotlib.rcdefaults()

# %%
B_V= pd.DataFrame(df_phys['BMag_6a_tau^NEB'] - df_phys['VMag_6a_tau^NEB'])

plt.figure(figsize = (15, 8))

#plt.grid()
#bins = 20
import matplotlib
matplotlib.rcParams['axes.axisbelow'] = False

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())
sns.histplot(B_V[0], bins = bins, color = 'indianred', alpha = 0.7, edgecolor = 'black', linewidth = 2)

min_ylim, max_ylim = plt.ylim()
x = B_V[0]
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*1.1, max_ylim*0.9, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)

plt.xlabel('$\mathregular{B-V \; [mag]}$', fontsize = 30)
plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)

min_val = B_V[0].min()
max_val = B_V[0].max()
val_width = max_val - min_val
n_bins = 15
bin_width = val_width/n_bins
plt.xticks(np.around(np.arange(min_val-bin_width/2, max_val+bin_width/2, bin_width), decimals = 2))

#plt.xticks(np.round(np.arange(-(1.17)/15, 2, step= (1.17)/15), decimals=2))
plt.title('B-V color index distribution at 1.5 < z < 2.5', fontsize = 35)

#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30)

plt.plot()

matplotlib.rcdefaults()

# %%
masa = df_mass['M_neb_med']
sfr = np.log10(df_phys['SFR_14a'])
sSFR = pd.DataFrame(sfr-masa)
sSFR.columns = ['sSFR']


B_V= pd.DataFrame(df_phys['BMag_6a_tau^NEB'] - df_phys['VMag_6a_tau^NEB'])

plt.figure(figsize = (15, 8))

#plt.grid()
#bins = 20
import matplotlib
matplotlib.rcParams['axes.axisbelow'] = False

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())

matplotlib.rc('xtick', labelsize=15) 

sns.histplot(sSFR['sSFR'], bins = bins, color = 'goldenrod', alpha = 0.7, edgecolor = 'black', linewidth = 2)

min_ylim, max_ylim = plt.ylim()
x = sSFR['sSFR']
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*0.98, max_ylim*0.9, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)

plt.xlabel('$\mathregular{sSFR}$ $\mathregular{[yr^{-1}]}$', fontsize = 30)
plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)

min_val = sSFR['sSFR'].min()
max_val = sSFR['sSFR'].max()
val_width = max_val - min_val
n_bins = 15
bin_width = val_width/n_bins
plt.xticks(np.around(np.arange(min_val-bin_width/2, max_val+bin_width/2, bin_width), decimals = 2))

#plt.xticks(np.round(np.arange(-(1.17)/15, 2, step= (1.17)/15), decimals=2))
plt.title('$\mathregular{log_{10}(sSFR)}$ distribution at 1.5 < z < 2.5', fontsize = 35)

#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30)

plt.plot()

matplotlib.rcdefaults()

# %%
plt.figure(figsize = (15, 8))

#plt.grid()
#bins = 20
import matplotlib
matplotlib.rcParams['axes.axisbelow'] = False

sns.set_style("whitegrid")
sns.set_context('talk')
bins = 1 + np.log2(len(df_phys))
bins = int(bins.round())

matplotlib.rc('xtick', labelsize=15) 

sns.histplot(df_phys['age_14a'], bins = bins, color = 'slategray', alpha = 0.7, edgecolor = 'black', linewidth = 2)

min_ylim, max_ylim = plt.ylim()
x = df_phys['age_14a']
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)
plt.text(x.mean()*1.01, max_ylim*0.9, 'mean value: {:.2f}'.format(x.mean()), fontsize = 30)

plt.xlabel('$\mathregular{log_{10}(age)}$ $\mathregular{[yr]}$', fontsize = 30)
plt.ylabel('Número de ocurrencias', fontsize = 30)
plt.ylabel(' ', fontsize = 1)

min_val = df_phys['age_14a'].min()
max_val = df_phys['age_14a'].max()
val_width = max_val - min_val
n_bins = 15
bin_width = val_width/n_bins
plt.xticks(np.around(np.arange(min_val-bin_width/2, max_val+bin_width/2, bin_width), decimals = 2))

#plt.xticks(np.round(np.arange(-(1.17)/15, 2, step= (1.17)/15), decimals=2))
plt.title('$\mathregular{log_{10}(age)}$ distribution at 1.5 < z < 2.5', fontsize = 35)

#plt.figtext(0.5, 0.01, "Para el número de bins se ha empleado: $\mathregular{bins = 1+ceil(log_2(nº}$ $\mathregular{datos))}$ ", ha="center", fontsize=30)

plt.plot()

matplotlib.rcdefaults()
